# %%
# Milestone 3. SQL table alterations.

from IPython.display import Image

# Task 1.
Image(filename="/Users/eglute/Desktop/T1.png")

# %%
# Task 2.
Image(filename="/Users/eglute/Desktop/T2.png")

# %%
# Task 3.
Image(filename="/Users/eglute/Desktop/T3.png")

# %%
# Task 4
Image(filename="/Users/eglute/Desktop/T4_T5.png")

# %%
# Task 6
Image(filename="/Users/eglute/Desktop/T6.png")

# %%
# Task 7
Image(filename="/Users/eglute/Desktop/T7.png")

# %%
# Task 8
Image(filename="/Users/eglute/Desktop/T8.png")
